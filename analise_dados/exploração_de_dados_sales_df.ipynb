# %% [markdown]
# **ANÁLISE EXPLORATÓRIA DE DADOS**
#
# Usei como base o csv já tratado para estudar mais afundo e trazer insights de business sobre as vendas da empresa.

# %%
import pandas as pd

sales_tratado_df = pd.read_csv(r'C:\Users\luiza\Downloads\sales_kaggle\sales_df_tratado.csv')
sales_tratado_df
# Out:
# C:\Users\luiza\AppData\Local\Temp\ipykernel_24148\1648342816.py:3: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   sales_tratado_df = pd.read_csv(r'C:\Users\luiza\Downloads\sales_kaggle\sales_df_tratado.csv')
#             ID                   Produto     Categoria  \
# 0       147963             Flatscreen TV  Alimentation
# 1       141647              20in Monitor  Électronique
# 2       141646  Lightning Charging Cable  Alimentation
# 3       144994           ThinkPad Laptop  Alimentation
# 4       141644    AAA Batteries (4-pack)     Vêtements
# ...        ...                       ...           ...
# 185945  299125      USB-C Charging Cable     Vêtements
# 185946  311386  Apple Airpods Headphones  Électronique
# 185947  306655           ThinkPad Laptop        Sports
# 185948  306809        Macbook Pro Laptop        Sports
# 185949  314552    AAA Batteries (4-pack)  Alimentation
#
# ...
